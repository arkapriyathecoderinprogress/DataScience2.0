# %% [markdown]
# <a href="https://colab.research.google.com/github/arkapriyathecoderinprogress/DataScience2.0/blob/main/Movies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=bda5a973510a630638fee6591ab1044d&language=en-US&page=1')
temp_df=pd.DataFrame(response.json()['results'][['id','title','overview','release_date','popularity','vote_average','vote_count']])
# Out:
#         id                                          title  \
# 0      278                       The Shawshank Redemption
# 1      238                                  The Godfather
# 2      240                          The Godfather Part II
# 3      424                               Schindler's List
# 4      389                                   12 Angry Men
# 5      129                                  Spirited Away
# 6    19404                    Dilwale Dulhania Le Jayenge
# 7      155                                The Dark Knight
# 8   496243                                       Parasite
# 9      497                                 The Green Mile
# 10  372058                                     Your Name.
# 11     680                                   Pulp Fiction
# 12     122  The Lord of the Rings: The Return of the King
# 13      13                                   Forrest Gump
# 14     429                 The Good, the Bad and the Ugly
# ...

# %%
df=pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,468):
  response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=bda5a973510a630638fee6591ab1044d&language=en-US&page={}'.format(i))
  temp_df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
  df=pd.concat([df,temp_df],ignore_index=True)
df
# Out:
#           id                       title  \
# 0        278    The Shawshank Redemption
# 1        238               The Godfather
# 2        240       The Godfather Part II
# 3        424            Schindler's List
# 4        389                12 Angry Men
# ...      ...                         ...
# 18655  12142           Alone in the Dark
# 18656  13805              Disaster Movie
# 18657  11059           House of the Dead
# 18658  14164        Dragonball Evolution
# 18659  40016  Birdemic: Shock and Terror
#
#                                                 overview release_date  \
# 0      Framed in the 1940s for the double murder of h...   1994-09-23
# 1      Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2      In the continuing saga of the Corleone crime f...   1974-12-20
# 3      The true story of how businessman Oskar Schind...   1993-12-15
# 4      The defense and the prosecution have rested an...   1957-04-10
# ...

# %%
df.shape
# Out:
# (18660, 7)

# %%
df.to_csv('movies.csv')
